# %%
speech=""
with open('speech_for_char_text_split.txt', 'r') as f:
    speech+=f.read()

from langchain.text_splitter import CharacterTextSplitter
text_splitter=CharacterTextSplitter(chunk_size=10,chunk_overlap=1)
splitted=text_splitter.create_documents([speech])
splitted
# Out:
# Created a chunk of size 36, which is longer than the specified 10
# Created a chunk of size 66, which is longer than the specified 10
# Created a chunk of size 14, which is longer than the specified 10
# Created a chunk of size 58, which is longer than the specified 10
# Created a chunk of size 41, which is longer than the specified 10
# Created a chunk of size 32, which is longer than the specified 10
# Created a chunk of size 37, which is longer than the specified 10
# Created a chunk of size 46, which is longer than the specified 10
# Created a chunk of size 20, which is longer than the specified 10
# [Document(metadata={}, page_content='Hi this is a content generated by me'),
#  Document(metadata={}, page_content='for the demonstration of document loaders for langchain community'),
#  Document(metadata={}, page_content='welcoming you'),
#  Document(metadata={}, page_content='check documentation for the more type of document loaders'),
#  Document(metadata={}, page_content='RAG means Retrieval Augumented Generation'),
#  Document(metadata={}, page_content='It is a important part of Gen Ai'),
#  Document(metadata={}, page_content='Gen Ai is a trending field now a days'),
#  Document(metadata={}, page_content='It is important to understand basics of Gen Ai'),
#  Document(metadata={}, page_content='Python is must to do'),
#  Document(metadata={}, page_content='All the best')]

# %%
for doc in splitted:
    print(doc)
    print()
# Out:
# page_content='Hi this is a content generated by me'
#
# page_content='for the demonstration of document loaders for langchain community'
#
# page_content='welcoming you'
#
# page_content='check documentation for the more type of document loaders'
#
# page_content='RAG means Retrieval Augumented Generation'
#
# page_content='It is a important part of Gen Ai'
#
# page_content='Gen Ai is a trending field now a days'
#
# page_content='It is important to understand basics of Gen Ai'
#
# page_content='Python is must to do'
#
# page_content='All the best'
